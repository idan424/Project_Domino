# %%
import os
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/Project Domino/new Macros' + '/'

# %%
dirs = sorted([d for d in os.listdir(path) if 'sub' in d])

for d in dirs:
    n_epochs = len(np.load(f'{path}{d}/{d}_y.npy'))
    print(f'{d} has {n_epochs} epochs')
# Out:
# sub-006 has 49 epochs
# sub-011 has 71 epochs
# sub-013 has 108 epochs
# sub-014 has 102 epochs
# sub-015 has 97 epochs
# sub-016 has 85 epochs
# sub-017 has 49 epochs
# sub-018 has 99 epochs
# sub-023 has 93 epochs
# sub-030 has 86 epochs
